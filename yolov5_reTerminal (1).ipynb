# %% [markdown]
# ### Clone repo and install requirements.txt in a Python>=3.8.0 environment, including PyTorch>=1.8. **Before this Change run type as GPU**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone

# %% [markdown]
# ### change directery to yolov5 and install requirements

# %%
# %cd /content/yolov5
# !pip install -r requirements.txt  # install

# %% [markdown]
# ### Copy and paste Generated code from roboflow data set. Make sure to select yolov5.
# ![roboflow.PNG](data:image/png;base64,...)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Lu5MY6ITdeMKAlnAYP1t")
project = rf.workspace("ppe-wqipw").project("ppe-detection-public")
dataset = project.version(2).download("yolov5")

# %% [markdown]
# ### In your image set file there is a data.yaml file and copy paste this file path to data path.

# %%
# !python train.py --img 224 --epochs 3 --data /content/yolov5/ppe-detection-public-2/data.yaml --weights yolov5n.pt

# %% [markdown]
# ### After training there is a folder created automatically named train and inside that there is file also named exp.This folder contains **best.pt**. Check it out and run below.

# %%
# !python3 export.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 224 --batch 1 --include  tflite --int8

# %% [markdown]
# ### Save These 2 files in your computer for next steps . Back to Wiki:
# ![colab.PNG](data:image/png;base64,...)
